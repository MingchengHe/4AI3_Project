# %% [markdown]
# # **Packages**

# %%
import pandas as pd
import seaborn as sns
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # **Import files**

# %%
x_te_url = 'https://raw.githubusercontent.com/MingchengHe/4AI3_Project/main/x_te.csv'
x_te = pd.read_csv(x_te_url)
x_tr_url = 'https://raw.githubusercontent.com/MingchengHe/4AI3_Project/main/x_tr.csv'
x_tr = pd.read_csv(x_tr_url)
y_te_url = 'https://raw.githubusercontent.com/MingchengHe/4AI3_Project/main/y_te.csv'
y_te = pd.read_csv(y_te_url)
y_tr_url = 'https://raw.githubusercontent.com/MingchengHe/4AI3_Project/main/y_tr.csv'
y_tr = pd.read_csv(y_tr_url)

te_final_url = 'https://raw.githubusercontent.com/MingchengHe/4AI3_Project/main/te_final.csv'
te_final = pd.read_csv(te_final_url)

sample_url = 'https://raw.githubusercontent.com/MingchengHe/4AI3_Project/main/sampleSubmission.csv'
sample = pd.read_csv(sample_url)

# %% [markdown]
# # **Pick the best fitted 3 features for linear regression**
#
# As shown in preprocessing:
#
# {'Size': 0.08602317794696512,
#
#  'Type': 0.049081916214990584,
#
#  'Store': 0.01025846705811806,
#
#  'MarkDown1': 0.003222929213519521,
#
#  'MarkDown5': 0.002810155996216701,
#
#  'MarkDown4': 0.0017329768879476015,
#
#  'CPI': 0.000865890901337707,
#
#  'Unemployment': 0.0007919920485753851,
#
#  'Dept': 0.0006161780181603849,
#
#  'MarkDown2': 0.0006101498226765978,
#
#  'MarkDown3': 0.000526816319086354,
#
#  'Temperature': 0.00028672877159852117,
#
#  'Date': 6.080727539348185e-05,
#
#  'IsHoliday': 1.3425095803709652e-05,
#
#  'Fuel_Price': 5.779071924338908e-07}
#
#  Most features have low correlation. Pick the top three.

# %%
x_tr_select = x_tr[['Size', 'Type', 'Store']]
x_te_select = x_te[['Size', 'Type', 'Store']]

# %%
x_tr_select
# Out:
#             Size      Type     Store
# 0      -0.525760  0.600907  0.993661
# 1       1.069164 -0.896723 -0.648860
# 2      -0.265302  0.600907 -0.023138
# 3       1.115823 -0.896723 -0.179568
# 4      -0.697907  0.600907 -0.414214
# ...          ...       ...       ...
# 309536  1.123074 -0.896723  0.367939
# 309537  0.317532 -0.896723  1.384738
# 309538  1.069164 -0.896723 -0.648860
# 309539 -1.288369  0.600907 -0.492429
# 309540  1.376347 -0.896723 -0.727075
#
# [309541 rows x 3 columns]

# %%
x_te_select
# Out:
#             Size      Type     Store
# 0       0.072822  0.600907 -0.101353
# 1      -0.247321  0.600907 -0.335999
# 2      -0.162339  0.600907 -1.039937
# 3      -0.247321  0.600907 -0.335999
# 4      -0.690524  0.600907  0.524370
# ...          ...       ...       ...
# 103176 -0.125032  0.600907  0.211508
# 103177 -1.613286  0.600907 -1.509228
# 103178  1.115954 -0.896723  0.680800
# 103179 -0.196725  0.600907 -0.570645
# 103180 -1.575585 -0.896723  0.837231
#
# [103181 rows x 3 columns]

# %% [markdown]
# # **Do linear regression on the top 3 features**

# %%
regr = LinearRegression()

regr.fit(x_tr_select, y_tr)
# Out:
# LinearRegression()

# %%
regr.score(x_te_select, y_te)
# Out:
# 0.08950193791013805

# %% [markdown]
# # **Score too bad. Try all features.**

# %%
regr = LinearRegression()

regr.fit(x_tr, y_tr)
# Out:
# LinearRegression()

# %%
regr.score(x_te, y_te)
# Out:
# 0.09281799989502704

# %% [markdown]
# # **Still bad. But it will be needed for prediction.**

# %%
prediction_array = regr.predict(te_final)

# %%
te_final
# Out:
#            Store      Dept      Date  IsHoliday  Temperature  Fuel_Price  \
# 0      -1.657956 -1.413724 -1.683055  -0.290032     0.073606   -0.816679
# 1      -1.657956 -1.381105 -1.683055  -0.290032     0.073606   -0.816679
# 2      -1.657956 -1.348485 -1.683055  -0.290032     0.073606   -0.816679
# 3      -1.657956 -1.315865 -1.683055  -0.290032     0.073606   -0.816679
# 4      -1.657956 -1.283245 -1.683055  -0.290032     0.073606   -0.816679
# ...          ...       ...       ...        ...          ...         ...
# 115059  1.776894  1.587292  1.692932  -0.290032     1.181271    0.929055
# 115060  1.776894  1.619912  1.692932  -0.290032     1.181271    0.929055
# 115061  1.776894  1.652532  1.692932  -0.290032     1.181271    0.929055
# 115062  1.776894  1.717771  1.692932  -0.290032     1.181271    0.929055
# 115063  1.776894  1.750391  1.692932  -0.290032     1.181271    0.929055
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5       CPI  \
# ...

# %%
prediction_array
# Out:
# array([[20.36694785],
#        [20.3774667 ],
#        [20.38798555],
#        ...,
#        [19.1639139 ],
#        [19.18495159],
#        [19.19547044]])

# %% [markdown]
# # **Processing of final result**

# %%
prediction = pd.DataFrame(prediction_array)
prediction.columns = ['Weekly_Sales_cbrt']

prediction['Weekly_Sales'] = prediction['Weekly_Sales_cbrt'].pow(3)

prediction
# Out:
#         Weekly_Sales_cbrt  Weekly_Sales
# 0               20.366948   8448.465871
# 1               20.377467   8461.562686
# 2               20.387986   8474.673028
# 3               20.398504   8487.796906
# 4               20.409023   8500.934326
# ...                   ...           ...
# 115059          19.142876   7014.901413
# 115060          19.153395   7026.471656
# 115061          19.163914   7038.054615
# 115062          19.184952   7061.258707
# 115063          19.195470   7072.879854
#
# [115064 rows x 2 columns]

# %%
sample['Weekly_Sales'] = prediction['Weekly_Sales']
sample
# Out:
#                       Id  Weekly_Sales
# 0         1_1_2012-11-02   8448.465871
# 1         1_1_2012-11-09   8461.562686
# 2         1_1_2012-11-16   8474.673028
# 3         1_1_2012-11-23   8487.796906
# 4         1_1_2012-11-30   8500.934326
# ...                  ...           ...
# 115059  45_98_2013-06-28   7014.901413
# 115060  45_98_2013-07-05   7026.471656
# 115061  45_98_2013-07-12   7038.054615
# 115062  45_98_2013-07-19   7061.258707
# 115063  45_98_2013-07-26   7072.879854
#
# [115064 rows x 2 columns]

# %%
sample.to_csv('Linear_Regression_Result.csv', index=False)
